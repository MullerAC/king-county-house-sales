# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
plt.style.use('seaborn')
# %matplotlib inline

# %%
df = pd.read_csv('data/cleaned_data.csv')
df.head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3       1.00         1180      5650     1.0
# 1  6414100192  538000.0         3       2.25         2570      7242     2.0
# 2  5631500400  180000.0         2       1.00          770     10000     1.0
# 3  2487200875  604000.0         4       3.00         1960      5000     1.0
# 4  1954400510  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  condition  grade  sqft_basement  yr_built  yr_renovated  \
# 0         0.0          3      7            0.0      1955           0.0
# 1         0.0          3      7          400.0      1951        1991.0
# 2         0.0          3      6            0.0      1933           0.0
# 3         0.0          5      7          910.0      1965           0.0
# 4         0.0          3      8            0.0      1987           0.0
#
#    zipcode      lat     long  yr_sold  yr_since_renovation  yr_since_built  \
# 0    98178  47.5112 -122.257     2014                 59.0              59
# 1    98125  47.7210 -122.319     2014                 23.0              63
# 2    98028  47.7379 -122.233     2015                 82.0              82
# 3    98136  47.5208 -122.393     2014                 49.0              49
# 4    98074  47.6168 -122.045     2015                 28.0              28
#
#    renovated
# 0          0
# 1          1
# 2          0
# 3          0
# 4          0

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.768984    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront     condition         grade  \
# count  2.159700e+04  21597.000000  21597.000000  21597.000000  21597.000000
# mean   1.509941e+04      1.494096      0.006760      3.409825      7.657915
# std    4.141264e+04      0.539683      0.081944      0.650546      1.173200
# min    5.200000e+02      1.000000      0.000000      1.000000      3.000000
# 25%    5.040000e+03      1.000000      0.000000      3.000000      7.000000
# 50%    7.618000e+03      1.500000      0.000000      3.000000      7.000000
# 75%    1.068500e+04      2.000000      0.000000      4.000000      8.000000
# max    1.651359e+06      3.500000      1.000000      5.000000     13.000000
#
#        sqft_basement      yr_built  yr_renovated       zipcode           lat  \
# count   21597.000000  21597.000000  21597.000000  21597.000000  21597.000000
# mean      285.716581   1970.999676     68.758207  98077.951845     47.560093
# std       439.819830     29.375234    364.037499     53.513072      0.138552
# min         0.000000   1900.000000      0.000000  98001.000000     47.155900
# 25%         0.000000   1951.000000      0.000000  98033.000000     47.471100
# 50%         0.000000   1975.000000      0.000000  98065.000000     47.571800
# 75%       550.000000   1997.000000      0.000000  98118.000000     47.678000
# max      4820.000000   2015.000000   2015.000000  98199.000000     47.777600
#
#                long       yr_sold  yr_since_renovation  yr_since_built  \
# count  21597.000000  21597.000000         21597.000000    21597.000000
# mean    -122.213982   2014.322962            41.377830       43.323286
# std        0.140724      0.467619            28.950873       29.377285
# min     -122.519000   2014.000000            -1.000000       -1.000000
# 25%     -122.328000   2014.000000            16.000000       18.000000
# 50%     -122.231000   2014.000000            37.000000       40.000000
# 75%     -122.125000   2015.000000            61.000000       63.000000
# max     -121.315000   2015.000000           115.000000      115.000000
#
#           renovated
# count  21597.000000
# mean       0.034449
# std        0.182384
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %% [markdown]
# # Which Features are Corolated with the Target

# %%
plt.figure(figsize=(15,30))
for i,col in enumerate(df.drop('price', axis=1).columns):
    ax = plt.subplot(8, 3, i+1)
    df.plot.scatter(x=col, y='price', ax=ax, legend=False)

# %% [markdown]
# Columns corrolating with Price:
#     - bedrooms
#     - bathrooms
#     - sqft_living
#     - sqft_lot
#     - sqft_basement
#     - yr_built
#
# Categorcial Data:
#     - Floors
#     - Condition
#     - Grade
#     - Zip Code
#
# Doesn't appear to be corrolated:
#     - Waterfront
#     - lat
#     - long
#     - yr_sold
#     - yr_since_renovation
#     - yr_since_built
#     - renovated
#
# Don't need to remove data unitil further analyzed.

# %% [markdown]
# # Features to Transform

# %%
df.hist(figsize = (20,18));

# %% [markdown]
# The only seemingly normal distribution is "grade". Consider log transforming continuous variables
#
# continuous variables:
#     - bathrooms
#     - sqft_living
#     - sqft_lot
#     - sqft_basement
#     - yr_built

# %%
df.yr_sold.value_counts()
# Out:
# 2014    14622
# 2015     6975
# Name: yr_sold, dtype: int64

# %% [markdown]
# Data is only for 2 years, drop yr_sold column

# %% [markdown]
# # What Features are Colliniar

# %%
corr = df.drop(['id', 'price'] , axis=1).corr()

df_corr=corr.abs().stack().reset_index().sort_values(0, ascending=False)
df_corr['pairs'] = list(zip(df_corr.level_0, df_corr.level_1))
df_corr.set_index(['pairs'], inplace = True)
df_corr.drop(columns=['level_1', 'level_0'], inplace = True)
df_corr.columns = ['cc']
df_corr.drop_duplicates(inplace=True)
df_corr[(df_corr.cc>.8) & (df_corr.cc <1)]
# Out:
#                                              cc
# pairs
# (yr_renovated, renovated)              0.999968
# (yr_built, yr_since_built)             0.999873
# (yr_since_renovation, yr_since_built)  0.926424
# (yr_since_renovation, yr_built)        0.926173

# %%
fig=plt.Figure(figsize=(25,15))
sns.heatmap(corr, center=0, annot=True);

# %% [markdown]
# In order to remove colliniarity, we will drop the yr_since_renovation, yr_built columns, and the yr_renovated columns.

# %%
corr = df.drop(['id', 'yr_built', 'yr_renovated', 'price', 'yr_sold', 'yr_since_renovation'] , axis=1).corr()

df_corr=corr.abs().stack().reset_index().sort_values(0, ascending=False)
df_corr['pairs'] = list(zip(df_corr.level_0, df_corr.level_1))
df_corr.set_index(['pairs'], inplace = True)
df_corr.drop(columns=['level_1', 'level_0'], inplace = True)
df_corr.columns = ['cc']
df_corr.drop_duplicates(inplace=True)
df_corr[(df_corr.cc>.8) & (df_corr.cc <1)]
# Out:
# Empty DataFrame
# Columns: [cc]
# Index: []

# %%
fig=plt.Figure(figsize=(25,15))
sns.heatmap(corr, center=0, annot=True);
